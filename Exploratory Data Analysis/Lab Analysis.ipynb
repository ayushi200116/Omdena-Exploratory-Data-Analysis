# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
with open("allData.pkl","rb") as f:
    d=pickle.load(f)

# %%
d.keys()
# Out:
# dict_keys(['Resources', 'TomQuality', 'CropParameters', 'LabAnalysis', 'Production', 'GrodanSens', 'GreenhouseClimate'])

# %%
labanalysis=d['LabAnalysis']

# %%
labanalysis.shape
# Out:
# (60, 39)

# %%
labanalysis.dtypes
# Out:
# %Time           int64
# irr_PH        float64
# irr_EC        float64
# irr_NH4       float64
# irr_K         float64
# irr_Na        float64
# irr_Ca        float64
# irr_Mg        float64
# irr_Si        float64
# irr_NO3       float64
# irr_Cl        float64
# irr_SO4       float64
# irr_HCO3      float64
# irr_PO4       float64
# irr_Fe        float64
# irr_Mn        float64
# irr_Zn        float64
# irr_B         float64
# irr_Cu        float64
# irr_Mo        float64
# drain_PH      float64
# drain_EC      float64
# drain_NH4     float64
# drain_K       float64
# drain_Na      float64
# drain_Ca      float64
# drain_Mg      float64
# drain_Si      float64
# drain_NO3     float64
# drain_Cl      float64
# drain_SO4     float64
# drain_HCO3    float64
# drain_PO4     float64
# drain_Fe      float64
# drain_Mn      float64
# drain_Zn      float64
# drain_B       float64
# drain_Cu      float64
# drain_Mo      float64
# dtype: object

# %%
labanalysis.nunique()
# Out:
# %Time         10
# irr_PH        18
# irr_EC        19
# irr_NH4       11
# irr_K         42
# irr_Na         4
# irr_Ca        33
# irr_Mg        28
# irr_Si         5
# irr_NO3       37
# irr_Cl        29
# irr_SO4       32
# irr_HCO3       7
# irr_PO4       39
# irr_Fe        38
# irr_Mn        37
# irr_Zn        35
# irr_B         35
# irr_Cu         9
# irr_Mo        25
# drain_PH      23
# drain_EC      29
# drain_NH4      7
# drain_K       43
# drain_Na      11
# drain_Ca      41
# drain_Mg      40
# drain_Si      31
# drain_NO3     47
# drain_Cl      37
# drain_SO4     39
# drain_HCO3    14
# drain_PO4     45
# drain_Fe      42
# drain_Mn      44
# drain_Zn      37
# drain_B       36
# drain_Cu      13
# drain_Mo      30
# dtype: int64

# %%
#View the data
labanalysis.head()
# Out:
#    %Time  irr_PH  irr_EC  irr_NH4  irr_K  irr_Na  irr_Ca  irr_Mg  irr_Si  \
# 0  43836     5.3     4.3      1.1   15.2     0.3     9.6     4.9    0.09
# 1  43850     5.2     4.0      1.1   11.3     0.3     9.8     4.1    0.09
# 2  43864     4.8     3.9      1.3   11.6     0.3    10.2     3.5    0.09
# 3  43879     4.8     3.7      1.4   13.3     0.4     8.2     2.8    0.09
# 4  43893     4.7     3.5      1.1   11.3     0.4     7.6     2.5    0.01
#
#    irr_NO3  ...  drain_Cl  drain_SO4  drain_HCO3  drain_PO4  drain_Fe  \
# 0     21.7  ...       7.6       13.5         1.4       2.00      27.8
# 1     21.0  ...      10.0       23.4         1.3       0.42      21.1
# 2     18.6  ...      12.0       17.5         1.0       1.30      18.3
# 3     16.0  ...      20.0       13.2         0.1       6.10      24.4
# 4     14.1  ...      21.2       11.6         0.1       9.32      31.0
#
#    drain_Mn  drain_Zn  drain_B  drain_Cu  drain_Mo
# 0       7.7       5.7     49.0       0.9      0.61
# ...

# %%
labanalysis.columns
# Out:
# Index(['%Time', 'irr_PH', 'irr_EC', 'irr_NH4', 'irr_K', 'irr_Na', 'irr_Ca',
#        'irr_Mg', 'irr_Si', 'irr_NO3', 'irr_Cl', 'irr_SO4', 'irr_HCO3',
#        'irr_PO4', 'irr_Fe', 'irr_Mn', 'irr_Zn', 'irr_B', 'irr_Cu', 'irr_Mo',
#        'drain_PH', 'drain_EC', 'drain_NH4', 'drain_K', 'drain_Na', 'drain_Ca',
#        'drain_Mg', 'drain_Si', 'drain_NO3', 'drain_Cl', 'drain_SO4',
#        'drain_HCO3', 'drain_PO4', 'drain_Fe', 'drain_Mn', 'drain_Zn',
#        'drain_B', 'drain_Cu', 'drain_Mo'],
#       dtype='object')

# %%
#Basic information
labanalysis.info()
#Describe the data
labanalysis.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 39 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   %Time       60 non-null     int64
#  1   irr_PH      60 non-null     float64
#  2   irr_EC      60 non-null     float64
#  3   irr_NH4     60 non-null     float64
#  4   irr_K       60 non-null     float64
#  5   irr_Na      60 non-null     float64
#  6   irr_Ca      60 non-null     float64
#  7   irr_Mg      60 non-null     float64
#  8   irr_Si      60 non-null     float64
#  9   irr_NO3     60 non-null     float64
#  10  irr_Cl      60 non-null     float64
#  11  irr_SO4     60 non-null     float64
#  12  irr_HCO3    60 non-null     float64
#  13  irr_PO4     60 non-null     float64
#  14  irr_Fe      60 non-null     float64
#  15  irr_Mn      60 non-null     float64
#  16  irr_Zn      60 non-null     float64
#  17  irr_B       60 non-null     float64
# ...

# %%
#Find NaN values
labanalysis.isna().sum()
# Out:
# %Time         0
# irr_PH        0
# irr_EC        0
# irr_NH4       0
# irr_K         0
# irr_Na        0
# irr_Ca        0
# irr_Mg        0
# irr_Si        0
# irr_NO3       0
# irr_Cl        0
# irr_SO4       0
# irr_HCO3      0
# irr_PO4       0
# irr_Fe        0
# irr_Mn        0
# irr_Zn        0
# irr_B         0
# irr_Cu        0
# irr_Mo        0
# drain_PH      0
# drain_EC      0
# drain_NH4     0
# drain_K       0
# drain_Na      0
# drain_Ca      0
# drain_Mg      0
# drain_Si      0
# drain_NO3     0
# drain_Cl      0
# drain_SO4     0
# drain_HCO3    0
# drain_PO4     0
# drain_Fe      0
# drain_Mn      0
# drain_Zn      0
# drain_B       0
# drain_Cu      0
# drain_Mo      0
# dtype: int64

# %%
labanalysis.head()
# Out:
#    %Time  irr_PH  irr_EC  irr_NH4  irr_K  irr_Na  irr_Ca  irr_Mg  irr_Si  \
# 0  43836     5.3     4.3      1.1   15.2     0.3     9.6     4.9    0.09
# 1  43850     5.2     4.0      1.1   11.3     0.3     9.8     4.1    0.09
# 2  43864     4.8     3.9      1.3   11.6     0.3    10.2     3.5    0.09
# 3  43879     4.8     3.7      1.4   13.3     0.4     8.2     2.8    0.09
# 4  43893     4.7     3.5      1.1   11.3     0.4     7.6     2.5    0.01
#
#    irr_NO3  ...  drain_Cl  drain_SO4  drain_HCO3  drain_PO4  drain_Fe  \
# 0     21.7  ...       7.6       13.5         1.4       2.00      27.8
# 1     21.0  ...      10.0       23.4         1.3       0.42      21.1
# 2     18.6  ...      12.0       17.5         1.0       1.30      18.3
# 3     16.0  ...      20.0       13.2         0.1       6.10      24.4
# 4     14.1  ...      21.2       11.6         0.1       9.32      31.0
#
#    drain_Mn  drain_Zn  drain_B  drain_Cu  drain_Mo
# 0       7.7       5.7     49.0       0.9      0.61
# ...

# %%
#renaming
labanalysis.rename(columns={'%Time': 'Time'}, inplace=True)
labanalysis.head()
# Out:
#     Time  irr_PH  irr_EC  irr_NH4  irr_K  irr_Na  irr_Ca  irr_Mg  irr_Si  \
# 0  43836     5.3     4.3      1.1   15.2     0.3     9.6     4.9    0.09
# 1  43850     5.2     4.0      1.1   11.3     0.3     9.8     4.1    0.09
# 2  43864     4.8     3.9      1.3   11.6     0.3    10.2     3.5    0.09
# 3  43879     4.8     3.7      1.4   13.3     0.4     8.2     2.8    0.09
# 4  43893     4.7     3.5      1.1   11.3     0.4     7.6     2.5    0.01
#
#    irr_NO3  ...  drain_Cl  drain_SO4  drain_HCO3  drain_PO4  drain_Fe  \
# 0     21.7  ...       7.6       13.5         1.4       2.00      27.8
# 1     21.0  ...      10.0       23.4         1.3       0.42      21.1
# 2     18.6  ...      12.0       17.5         1.0       1.30      18.3
# 3     16.0  ...      20.0       13.2         0.1       6.10      24.4
# 4     14.1  ...      21.2       11.6         0.1       9.32      31.0
#
#    drain_Mn  drain_Zn  drain_B  drain_Cu  drain_Mo
# 0       7.7       5.7     49.0       0.9      0.61
# ...

# %%
#changing time format
labanalysis['Time'] = pd.to_datetime(labanalysis['Time'], unit='D', origin='1899-12-30')

# %%
labanalysis.head()
# Out:
#         Time  irr_PH  irr_EC  irr_NH4  irr_K  irr_Na  irr_Ca  irr_Mg  irr_Si  \
# 0 2020-01-06     5.3     4.3      1.1   15.2     0.3     9.6     4.9    0.09
# 1 2020-01-20     5.2     4.0      1.1   11.3     0.3     9.8     4.1    0.09
# 2 2020-02-03     4.8     3.9      1.3   11.6     0.3    10.2     3.5    0.09
# 3 2020-02-18     4.8     3.7      1.4   13.3     0.4     8.2     2.8    0.09
# 4 2020-03-03     4.7     3.5      1.1   11.3     0.4     7.6     2.5    0.01
#
#    irr_NO3  ...  drain_Cl  drain_SO4  drain_HCO3  drain_PO4  drain_Fe  \
# 0     21.7  ...       7.6       13.5         1.4       2.00      27.8
# 1     21.0  ...      10.0       23.4         1.3       0.42      21.1
# 2     18.6  ...      12.0       17.5         1.0       1.30      18.3
# 3     16.0  ...      20.0       13.2         0.1       6.10      24.4
# 4     14.1  ...      21.2       11.6         0.1       9.32      31.0
#
#    drain_Mn  drain_Zn  drain_B  drain_Cu  drain_Mo
# ...

# %%
#correlation
plt.figure(figsize=(40,30))
sns.heatmap(labanalysis.corr(), annot=True)
# Out:
# <ipython-input-16-42e020470e38>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(labanalysis.corr(), annot=True)
# <AxesSubplot:>

# %%
correlations = labanalysis.corr()
cols = correlations
for i in cols:
    for j in cols:
         if i!=j and abs(correlations.loc[i, j])>= 0.6:
            print(f"{i} and {j} correlated with value {correlations.loc[i, j]}")
# Out:
# irr_EC and irr_K correlated with value 0.7546279976022602
# irr_EC and irr_Ca correlated with value 0.805745332504629
# irr_EC and irr_Mg correlated with value 0.808470408847406
# irr_EC and irr_Cl correlated with value 0.6775762652892551
# irr_EC and irr_SO4 correlated with value 0.8190664659182514
# irr_NH4 and irr_Zn correlated with value -0.679322887844954
# irr_NH4 and irr_Cu correlated with value -0.6331083271269051
# irr_K and irr_EC correlated with value 0.7546279976022602
# irr_K and irr_SO4 correlated with value 0.7556440046376731
# irr_Na and irr_Cl correlated with value 0.6179982741074971
# irr_Na and drain_Cl correlated with value 0.6265164576846841
# irr_Ca and irr_EC correlated with value 0.805745332504629
# irr_Ca and irr_Mg correlated with value 0.6446947989312006
# irr_Ca and irr_NO3 correlated with value 0.7015759840051299
# irr_Mg and irr_EC correlated with value 0.808470408847406
# irr_Mg and irr_Ca correlated with value 0.6446947989312006
# ...

# %%
#scatter plot with respect to time 
columns=['irr_PH', 'irr_EC', 'irr_NH4', 'irr_K', 'irr_Na', 'irr_Ca','irr_Mg', 'irr_Si', 'irr_NO3', 'irr_Cl', 'irr_SO4', 'irr_HCO3','irr_PO4', 'irr_Fe', 'irr_Mn', 'irr_Zn', 'irr_B', 'irr_Cu', 'irr_Mo','drain_PH', 'drain_EC', 'drain_NH4', 'drain_K', 'drain_Na', 'drain_Ca','drain_Mg', 'drain_Si', 'drain_NO3', 'drain_Cl', 'drain_SO4','drain_HCO3', 'drain_PO4', 'drain_Fe', 'drain_Mn', 'drain_Zn','drain_B', 'drain_Cu', 'drain_Mo']
for i in columns:
    labanalysis.plot(kind='scatter',x='Time', y=i, alpha=0.5, c='Time',cmap=plt.get_cmap("jet"))
# Out:
# C:\Users\singh\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:512: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
